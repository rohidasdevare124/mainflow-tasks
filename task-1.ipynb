# %%
import pandas as pd

# load dataset 
df = pd.read_csv("student-mat.csv", sep=';')

# show first five rows
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#Missing values
print("Missing values:\n",df.isnull().sum())
#Shape of the data
print("\nDataset shape:",df.shape)
# Out:
# Missing values:
#  school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64
#
# Dataset shape: (395, 33)

# %%
#Remove missing and duplicate data
df = df.dropna()
df= df.drop_duplicates()

print("Cleaned dataset shape:",df.shape)
# Out:
# Cleaned dataset shape: (395, 33)

# %%
#The average score in math (G3)

avg_g3 = df["G3"].mean()
print("Average Final score (G3):",avg_g3)
# Out:
# Average Final score (G3): 10.415189873417722

# %%
#Students scored above 15 in their final grade (G3)

count_above_15 = (df["G3"]>15).sum()
print("Number of students with G3 > 15 :",count_above_15)
# Out:
# Number of students with G3 > 15 : 40

# %%
#Correlation between study time (study time) and the final grade (G3)

correlation = df["studytime"].corr(df["G3"])
print("Correlation between study time and G3 :",correlation)
# Out:
# Correlation between study time and G3 : 0.09781968965319626

# %%
# Gender which has higher average final grade (G3)

gender_avg = df.groupby("sex")["G3"].mean()
print("Average G3 by gender:\n",gender_avg)
# Out:
# Average G3 by gender:
#  sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %%
# Plot a histogram of final grades (G3)

import matplotlib.pyplot as plt

plt.hist(df["G3"], bins=10, color='yellow', edgecolor='black')
plt.title("Histogram of Final Grades (G3)")
plt.xlabel("Final Grade")
plt.ylabel("Number of Students")
plt.show()

# %%
# Scatter plot between study time and final grade (G3).

import matplotlib.pyplot as plt

plt.scatter(df["studytime"], df["G3"], color='blue')
plt.title("Study Time vs Final Grade (G3)")
plt.xlabel("Study Time (hours/week)")
plt.ylabel("Final Grade (G3)")
plt.show()

# %%
# Bar chart comparing the average scores of male and female students.

gender_avg.plot(kind='bar', color=['pink', 'skyblue'])
plt.title("Average Final Grade by Gender")
plt.xlabel("Gender")
plt.ylabel("Average G3")
plt.xticks(rotation=0)
plt.show()
